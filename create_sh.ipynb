# %%
lambdas = [0.0, 0.3, 0.7, 0.9, 1.0]
alphas = [1/4, 1/8, 1/16]
seeds = list(range(10))

# %%
c = 0
for l in lambdas:
    for a in alphas:
        for seed in seeds:
            print('python evaluate_tdlambda.py --save_dir expe1 --lambda {} --alpha {} --seed {} &'.format(l, a, seed))
            if c % 12 == 0:
                print('wait')
            c += 1
# Out:
# python evaluate_tdlambda.py --save_dir expe1 --lambda 0.0 --alpha 0.25 --seed 0 &
# wait
# python evaluate_tdlambda.py --save_dir expe1 --lambda 0.0 --alpha 0.25 --seed 1 &
# python evaluate_tdlambda.py --save_dir expe1 --lambda 0.0 --alpha 0.25 --seed 2 &
# python evaluate_tdlambda.py --save_dir expe1 --lambda 0.0 --alpha 0.25 --seed 3 &
# python evaluate_tdlambda.py --save_dir expe1 --lambda 0.0 --alpha 0.25 --seed 4 &
# python evaluate_tdlambda.py --save_dir expe1 --lambda 0.0 --alpha 0.25 --seed 5 &
# python evaluate_tdlambda.py --save_dir expe1 --lambda 0.0 --alpha 0.25 --seed 6 &
# python evaluate_tdlambda.py --save_dir expe1 --lambda 0.0 --alpha 0.25 --seed 7 &
# python evaluate_tdlambda.py --save_dir expe1 --lambda 0.0 --alpha 0.25 --seed 8 &
# python evaluate_tdlambda.py --save_dir expe1 --lambda 0.0 --alpha 0.25 --seed 9 &
# python evaluate_tdlambda.py --save_dir expe1 --lambda 0.0 --alpha 0.125 --seed 0 &
# ...
