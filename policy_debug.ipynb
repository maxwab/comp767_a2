# %%
import numpy as np

# %%
obs = np.array([[0.2, -0.3, -2.3],
               [-0.4, 0.1, 1.4],
               [-0.4, 0.1, 0.0]])

# %%
import policy

# %%
cp = 0
cm = 0
as_ = []
for j in range(1000):
    a = policy.policy(obs)
    print('Action chosen: {}'.format(a))
    as_.append(a)
# Out:
# Action chosen: [-0.1  0.1  0.1]
# Action chosen: [-0.1  0.1  0.1]
# Action chosen: [-0.1 -0.1  0.1]
# Action chosen: [-0.1  0.1 -0.1]
# Action chosen: [-0.1  0.1  0.1]
# Action chosen: [-0.1  0.1  0.1]
# Action chosen: [-0.1  0.1  0.1]
# Action chosen: [-0.1  0.1 -0.1]
# Action chosen: [-0.1  0.1 -0.1]
# Action chosen: [-0.1  0.1 -0.1]
# Action chosen: [-0.1  0.1  0.1]
# Action chosen: [-0.1  0.1 -0.1]
# Action chosen: [-0.1  0.1  0.1]
# Action chosen: [-0.1  0.1  0.1]
# Action chosen: [-0.1  0.1 -0.1]
# Action chosen: [0.1 0.1 0.1]
# Action chosen: [-0.1  0.1 -0.1]
# Action chosen: [-0.1  0.1 -0.1]
# Action chosen: [-0.1  0.1  0.1]
# Action chosen: [-0.1  0.1 -0.1]
# Action chosen: [-0.1 -0.1 -0.1]
# Action chosen: [-0.1 -0.1  0.1]
# Action chosen: [-0.1  0.1 -0.1]
# Action chosen: [-0.1  0.1  0.1]
# Action chosen: [-0.1  0.1  0.1]
# Action chosen: [-0.1  0.1 -0.1]
# Action chosen: [-0.1  0.1  0.1]
# Action chosen: [-0.1  0.1 -0.1]
# Action chosen: [0.1 0.1 0.1]
# ...

# %%
res = np.stack(as_, 0)

# %%
(res > 0).astype(int).sum(0)
# Out:
# array([103, 905, 509])
